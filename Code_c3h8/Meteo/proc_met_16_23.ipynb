# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.pyplot import figure
import glob
import os
import metpy
import metpy.calc as mpcalc
from metpy.units import units
import numpy as np
from datetime import datetime
import xarray as xr
from pint import UnitRegistry
ureg = UnitRegistry()
import seaborn as sns
from scipy import stats
from scipy.stats import f_oneway
import statsmodels.api as sm

# %%
# Function to extract epoch from the first few rows of the CSV file
def extract_epoch_from_header(file):
    # Read the first few lines to find the epoch (assuming it's in a comment or a header)
    with open(file, 'r') as f:
        skiprow = f.readline()
        skiprow = skiprow.strip().split()[0]
        for line in f:
            if "startdate:" in line.lower():  # Assuming the word 'epoch' is present in the line
                # Extract the epoch date (this assumes the date is the second item in the line)
                epoch = line.strip().split()[1]
                return int(skiprow)-1, epoch[0:4]+"-"+epoch[4:6]+"-"+epoch[6:8]+" "+epoch[8:10]+":"+epoch[10:12]+":"+epoch[12:14]
    return None  # Return None if no epoch is found

# Function to load and adjust time for each CSV
def load_and_adjust_time(file):
    # Try to extract the epoch from the header or a specific column
    nskiprows,epoch = extract_epoch_from_header(file)
   
    if epoch is None:
        raise ValueError(f"Could not find epoch for file: {file}")
   
    # Load the actual data (skipping header if necessary)
    df = pd.read_csv(file, skiprows=nskiprows,sep="\\s+")  # Adjust skiprows based on where the data starts
   
    # Convert 'time' column to a datetime, assuming it's in days
    # Adjust time column to start from the epoch time found in the file
    df['starttime_dt'] = pd.to_timedelta(df['starttime'], unit='D') + pd.Timestamp(epoch)
   
    # Return the adjusted DataFrame
    return df

# %%
#set a working directory till NMVOC folder
working_dir = "C:\\Year1\\"
# Find all CSV files (change the path if nedeed)
wind_s_files = glob.glob(working_dir+"NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1137\\*.nas")

print(wind_s_files)

# this function reads and adjust times for all CSV files
dfs = []
for file in wind_s_files:
    df = load_and_adjust_time(file)
    dfs.append(df)

# concatenates all DataFrames (based on time)
wind_s_df = pd.concat(dfs,axis=0,ignore_index=True)

# Show combined DataFrame
print(wind_s_df)
# Out:
# ['C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1137\\IT0009R.20160101000000.20170511000000.aws.wind_speed.met.1y.1h.IT06L_CIM_WS425.IT06L_WS425.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1137\\IT0009R.20170101000000.20180309133800.aws.wind_speed.met.1y.1h.IT06L_CIM_WS425.IT06L_WS425.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1137\\IT0009R.20180101000000.20200105091500.aws.wind_speed.met.1y.1h.IT06L_CIM_WS425.IT06L_WS425.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1137\\IT0009R.20190101000000.20210108101537.aws.wind_speed.met.52w.1h.IT06L_CIM_WS425.IT06L_WS425.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1137\\IT0009R.20200101000000.20231204154530.aws.wind_speed.met.1y.1h.IT06L_CIM_WS425.IT06L_WS425.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1137\\IT0009R.20210101000000.20220314111200.aws.wind_speed.met.1y.1h.IT06L_CIM_WS425.IT06L_WS425.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1137\\IT0009R.20220101000000.20230327143700.aws.wind_speed.met.1y.1h.IT06L_CIM_WS425.IT06L_WS425.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1137\\IT0009R.20230101000000.20240308131800.aws.wind_speed.met.1y.1h.IT06L_CIM_WS425.IT06L_WS425.lev2.nas']
#         starttime     endtime  wind_s  flag_wind_s               starttime_dt
# 0        0.000000    0.041667    5.80          0.0 2016-01-01 00:00:00.000000
# 1        0.041667    0.083333    6.10          0.0 2016-01-01 01:00:00.028800
# 2        0.083333    0.125000    3.90          0.0 2016-01-01 01:59:59.971200
# 3        0.125000    0.166667    1.20          0.0 2016-01-01 03:00:00.000000
# 4        0.166667    0.208333    1.10          0.0 2016-01-01 04:00:00.028800
# ...           ...         ...     ...          ...                        ...
# 70033  364.791667  364.833333    5.77          0.0 2023-12-31 19:00:00.028800
# 70034  364.833333  364.875000    6.08          0.0 2023-12-31 19:59:59.971200
# 70035  364.875000  364.916667    6.84          0.0 2023-12-31 21:00:00.000000
# 70036  364.916667  364.958333    6.33          0.0 2023-12-31 22:00:00.028800
# 70037  364.958333  365.000000    5.56          0.0 2023-12-31 22:59:59.971200
#
# [70038 rows x 5 columns]

# %%
wind_s_df["starttime"].plot()
# Out:
# <Axes: >

# %%
#set a working directory till NMVOC folder
working_dir = "C:\\Year1\\"
# Find all CSV files (change the path if nedded)
temp_files = glob.glob(working_dir+"NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1140\\*.nas")                       
print(temp_files)

# this function reads and adjust times for all CSV files
dfs = []
for file in temp_files:
    df = load_and_adjust_time(file)
    dfs.append(df)

# concatenates all DataFrames (based on time)

temp_df = pd.concat(dfs,axis=0,ignore_index=True)
# Show combined DataFrame
print(temp_df)
# Out:
# ['C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1140\\IT0009R.20150101000000.20160722000000.aws.temperature.met.1y.1h.IT06L_aws_it0009.IT06L_aws.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1140\\IT0009R.20160101000000.20170511000000.aws.temperature.met.1y.1h.IT06L_CIM_Rotronic.IT06L_Rotronic.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1140\\IT0009R.20170101000000.20180309133800.aws.temperature.met.1y.1h.IT06L_CIM_Rotronic.IT06L_Rotronic.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1140\\IT0009R.20180101000000.20200105091500.aws.temperature.met.1y.1h.IT06L_CIM_Rotronic.IT06L_Rotronic.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1140\\IT0009R.20190101000000.20210108101537.aws.temperature.met.52w.1h.IT06L_CIM_Rotronic.IT06L_Rotronic.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1140\\IT0009R.20200101000000.20210212120500.aws.temperature.met.1y.1h.IT06L_CIM_Rotronic.IT06L_Rotronic.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1140\\IT0009R.20210101000000.20220314111200.aws.temperature.met.1y.1h.IT06L_CIM_HMP155.IT06L_CIM_HMP155.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1140\\IT0009R.20220101000000.20230327143700.aws.temperature.met.1y.1h.IT06L_CIM_HMP155.IT06L_CIM_HMP155.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1140\\IT0009R.20230101000000.20240308131800.aws.temperature.met.1y.1h.IT06L_CIM_HMP155.IT06L_CIM_HMP155.lev2.nas']
#         starttime     endtime      T  flag_T               starttime_dt
# 0        0.000000    0.041667 -12.60     0.0 2015-01-01 00:00:00.000000
# 1        0.041667    0.083333 -12.20     0.0 2015-01-01 01:00:00.028800
# 2        0.083333    0.125000 -11.60     0.0 2015-01-01 01:59:59.971200
# 3        0.125000    0.166667 -11.00     0.0 2015-01-01 03:00:00.000000
# 4        0.166667    0.208333 -10.90     0.0 2015-01-01 04:00:00.028800
# ...           ...         ...    ...     ...                        ...
# 78774  364.791667  364.833333   0.83     0.0 2023-12-31 19:00:00.028800
# 78775  364.833333  364.875000   0.53     0.0 2023-12-31 19:59:59.971200
# 78776  364.875000  364.916667   0.12     0.0 2023-12-31 21:00:00.000000
# 78777  364.916667  364.958333   0.26     0.0 2023-12-31 22:00:00.028800
# 78778  364.958333  365.000000   0.23     0.0 2023-12-31 22:59:59.971200
#
# [78779 rows x 5 columns]

# %%
temp_df["starttime"].plot()
# Out:
# <Axes: >

# %%
#set a working directory till NMVOC folder
working_dir = "C:\\Year1\\"
# Find all CSV files (change the path if nedeed)
RH_files = glob.glob(working_dir+"NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1134\\*.nas") 
print(RH_files)

# this function reads and adjust times for all CSV files
dfs = []
for file in RH_files:
    df = load_and_adjust_time(file)
    dfs.append(df)

# concatenates all DataFrames (based on time)
RH_df  = pd.concat(dfs,axis=0,ignore_index=True)


# Show combined DataFrame
print(RH_df)
# Out:
# ['C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1134\\IT0009R.20150101000000.20160722000000.aws.relative_humidity.met.1y.1h.IT06L_aws_it0009.IT06L_aws.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1134\\IT0009R.20160101000000.20170511000000.aws.relative_humidity.met.1y.1h.IT06L_CIM_Rotronic.IT06L_Rotronics.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1134\\IT0009R.20170101000000.20180309133800.aws.relative_humidity.met.1y.1h.IT06L_CIM_Rotronic.IT06L_Rotronics.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1134\\IT0009R.20180101000000.20200105091500.aws.relative_humidity.met.1y.1h.IT06L_CIM_Rotronic.IT06L_Rotronics.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1134\\IT0009R.20190101000000.20210108101537.aws.relative_humidity.met.52w.1h.IT06L_CIM_Rotronic.IT06L_Rotronics.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1134\\IT0009R.20200101000000.20210212120500.aws.relative_humidity.met.1y.1h.IT06L_CIM_Rotronic.IT06L_Rotronics.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1134\\IT0009R.20210101000000.20220314111200.aws.relative_humidity.met.1y.1h.IT06L_CIM_HMP155.IT06L_CIM_HMP155.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1134\\IT0009R.20220101000000.20230327143700.aws.relative_humidity.met.1y.1h.IT06L_CIM_HMP155.IT06L_CIM_HMP155.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240920_1134\\IT0009R.20230101000000.20240308131800.aws.relative_humidity.met.1y.1h.IT06L_CIM_HMP155.IT06L_CIM_HMP155.lev2.nas']
#         starttime     endtime    rH  flag_rH               starttime_dt
# 0        0.000000    0.041667  85.3      0.0 2015-01-01 00:00:00.000000
# 1        0.041667    0.083333  85.7      0.0 2015-01-01 01:00:00.028800
# 2        0.083333    0.125000  87.0      0.0 2015-01-01 01:59:59.971200
# 3        0.125000    0.166667  84.2      0.0 2015-01-01 03:00:00.000000
# 4        0.166667    0.208333  83.5      0.0 2015-01-01 04:00:00.028800
# ...           ...         ...   ...      ...                        ...
# 78774  364.791667  364.833333  91.0      0.0 2023-12-31 19:00:00.028800
# 78775  364.833333  364.875000  91.0      0.0 2023-12-31 19:59:59.971200
# 78776  364.875000  364.916667  91.0      0.0 2023-12-31 21:00:00.000000
# 78777  364.916667  364.958333  91.0      0.0 2023-12-31 22:00:00.028800
# 78778  364.958333  365.000000  91.0      0.0 2023-12-31 22:59:59.971200
#
# [78779 rows x 5 columns]

# %%
RH_df["starttime"].plot()
# Out:
# <Axes: >

# %%
#set a working directory till NMVOC folder
working_dir = "C:\\Year1\\"
# Find all CSV files (change the path if nedeed)
pressure_files = glob.glob(working_dir+"NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240923_1438\\*.nas")
print(pressure_files)

# this function reads and adjust times for all CSV files
dfs = []
for file in pressure_files:
    df = load_and_adjust_time(file)
    dfs.append(df)


# concatenates all DataFrames (based on time)
pressure_df  = pd.concat(dfs,axis=0,ignore_index=True)

# Show combined DataFrame
print(pressure_df)
# Out:
# ['C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240923_1438\\IT0009R.20150101000000.20160722000000.aws.pressure.met.1y.1h.IT06L_aws_it0009.IT06L_aws.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240923_1438\\IT0009R.20160101000000.20170511000000.aws.pressure.met.1y.1h.IT06L_CIM_Technoel.IT06L_Technoel.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240923_1438\\IT0009R.20170101000000.20180309133800.aws.pressure.met.1y.1h.IT06L_CIM_Technoel.IT06L_Technoel.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240923_1438\\IT0009R.20180101000000.20200105091500.aws.pressure.met.1y.1h.IT06L_CIM_Technoel.IT06L_Technoel.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240923_1438\\IT0009R.20190101000000.20210108101537.aws.pressure.met.52w.1h.IT06L_CIM_Technoel.IT06L_Technoel.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240923_1438\\IT0009R.20200101000000.20210212120500.aws.pressure.met.1y.1h.IT06L_CIM_Technoel.IT06L_Technoel.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240923_1438\\IT0009R.20210101000000.20220314111200.aws.pressure.met.1y.1h.IT06L_CIM_PTB210.IT06L_CIM_PTB210.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240923_1438\\IT0009R.20220101000000.20230327143700.aws.pressure.met.1y.1h.IT06L_CIM_PTB210.IT06L_CIM_PTB210.lev2.nas', 'C:\\Year1\\NMVOC\\Data\\data_Meteo\\Meteo_ebas_CMN_16_23\\Ebas_240923_1438\\IT0009R.20230101000000.20240308131800.aws.pressure.met.1y.1h.IT06L_CIM_PTB210.IT06L_CIM_PTB210.lev2.nas']
#         starttime     endtime       P  flag_P               starttime_dt
# 0        0.000000    0.041667  798.50     0.0 2015-01-01 00:00:00.000000
# 1        0.041667    0.083333  798.50     0.0 2015-01-01 01:00:00.028800
# 2        0.083333    0.125000  798.50     0.0 2015-01-01 01:59:59.971200
# 3        0.125000    0.166667  797.60     0.0 2015-01-01 03:00:00.000000
# 4        0.166667    0.208333  796.70     0.0 2015-01-01 04:00:00.028800
# ...           ...         ...     ...     ...                        ...
# 78774  364.791667  364.833333  777.50     0.0 2023-12-31 19:00:00.028800
# 78775  364.833333  364.875000  776.73     0.0 2023-12-31 19:59:59.971200
# 78776  364.875000  364.916667  775.83     0.0 2023-12-31 21:00:00.000000
# 78777  364.916667  364.958333  776.62     0.0 2023-12-31 22:00:00.028800
# 78778  364.958333  365.000000  777.26     0.0 2023-12-31 22:59:59.971200
#
# [78779 rows x 5 columns]

# %%
pressure_df["starttime"].plot()
# Out:
# <Axes: >

# %%
df=wind_s_df
df['T'] = temp_df['T']
df['rH'] = RH_df.rH
df['P'] = pressure_df['P']
df['flag_T'] = temp_df.flag_T
df['flag_P'] = pressure_df.flag_P
df['flag_rH'] = RH_df.flag_rH
df
# Out:
#         starttime     endtime  wind_s  flag_wind_s               starttime_dt  \
# 0        0.000000    0.041667    5.80          0.0 2016-01-01 00:00:00.000000
# 1        0.041667    0.083333    6.10          0.0 2016-01-01 01:00:00.028800
# 2        0.083333    0.125000    3.90          0.0 2016-01-01 01:59:59.971200
# 3        0.125000    0.166667    1.20          0.0 2016-01-01 03:00:00.000000
# 4        0.166667    0.208333    1.10          0.0 2016-01-01 04:00:00.028800
# ...           ...         ...     ...          ...                        ...
# 70033  364.791667  364.833333    5.77          0.0 2023-12-31 19:00:00.028800
# 70034  364.833333  364.875000    6.08          0.0 2023-12-31 19:59:59.971200
# 70035  364.875000  364.916667    6.84          0.0 2023-12-31 21:00:00.000000
# 70036  364.916667  364.958333    6.33          0.0 2023-12-31 22:00:00.028800
# 70037  364.958333  365.000000    5.56          0.0 2023-12-31 22:59:59.971200
#
#            T    rH       P  flag_T  flag_P  flag_rH
# 0     -12.60  85.3  798.50     0.0     0.0      0.0
# 1     -12.20  85.7  798.50     0.0     0.0      0.0
# 2     -11.60  87.0  798.50     0.0     0.0      0.0
# 3     -11.00  84.2  797.60     0.0     0.0      0.0
# 4     -10.90  83.5  796.70     0.0     0.0      0.0
# ...      ...   ...     ...     ...     ...      ...
# 70033   4.13  77.0  795.56     0.0     0.0      0.0
# 70034   3.23  88.0  795.59     0.0     0.0      0.0
# 70035   3.22  86.0  795.71     0.0     0.0      0.0
# 70036   3.13  85.0  795.85     0.0     0.0      0.0
# 70037   3.59  80.0  796.01     0.0     0.0      0.0
#
# [70038 rows x 11 columns]

# %%
#remove lines depending on flags
df = df[df.flag_wind_s != 0.999]
df = df[df.flag_rH != 0.999]
df = df[df.flag_T != 0.999]
df = df[df.flag_P != 0.999]
df = df[df.flag_wind_s != 0.899]
df = df[df.flag_rH != 0.899]
df = df[df.flag_T != 0.899]
df = df[df.flag_wind_s != 0.456]
df = df[df.flag_rH != 0.456]
df = df[df.flag_T != 0.456]
df = df[df.flag_P != 0.456]
df = df[df.flag_wind_s != 0.260]
df = df[df.flag_rH != 0.260]
df = df[df.flag_T != 0.260]
df = df[df.flag_P != 0.260]
df = df[df.flag_wind_s != 0.259]
df = df[df.flag_rH != 0.259]
df = df[df.flag_T != 0.259]
df = df[df.flag_P != 0.259]
df = df[df.flag_wind_s != 0.256]
df = df[df.flag_rH != 0.255]
df = df[df.flag_T != 0.255]
df = df[df.flag_P != 0.255]
df = df[df.flag_wind_s != 99999.99]
df = df[df.rH != 99999.99]
df = df[df['T'] != 99999.99]

df.index = df["starttime_dt"]
#remove useless columns
df = df.drop(columns=["flag_wind_s"])
df = df.drop(columns=["flag_rH"])
df = df.drop(columns=["flag_T"])
df = df.drop(columns=["flag_P"])
df = df.drop(columns=["starttime"])
df = df.drop(columns=["endtime"])
df
# Out:
#                             wind_s               starttime_dt      T    rH  \
# starttime_dt
# 2016-01-01 00:00:00.000000    5.80 2016-01-01 00:00:00.000000 -12.60  85.3
# 2016-01-01 01:00:00.028800    6.10 2016-01-01 01:00:00.028800 -12.20  85.7
# 2016-01-01 01:59:59.971200    3.90 2016-01-01 01:59:59.971200 -11.60  87.0
# 2016-01-01 03:00:00.000000    1.20 2016-01-01 03:00:00.000000 -11.00  84.2
# 2016-01-01 04:00:00.028800    1.10 2016-01-01 04:00:00.028800 -10.90  83.5
# ...                            ...                        ...    ...   ...
# 2023-12-31 19:00:00.028800    5.77 2023-12-31 19:00:00.028800   4.13  77.0
# 2023-12-31 19:59:59.971200    6.08 2023-12-31 19:59:59.971200   3.23  88.0
# 2023-12-31 21:00:00.000000    6.84 2023-12-31 21:00:00.000000   3.22  86.0
# 2023-12-31 22:00:00.028800    6.33 2023-12-31 22:00:00.028800   3.13  85.0
# 2023-12-31 22:59:59.971200    5.56 2023-12-31 22:59:59.971200   3.59  80.0
#
#                                  P
# starttime_dt
# 2016-01-01 00:00:00.000000  798.50
# 2016-01-01 01:00:00.028800  798.50
# 2016-01-01 01:59:59.971200  798.50
# 2016-01-01 03:00:00.000000  797.60
# 2016-01-01 04:00:00.028800  796.70
# ...                            ...
# 2023-12-31 19:00:00.028800  795.56
# 2023-12-31 19:59:59.971200  795.59
# 2023-12-31 21:00:00.000000  795.71
# 2023-12-31 22:00:00.028800  795.85
# 2023-12-31 22:59:59.971200  796.01
#
# [56032 rows x 5 columns]

# %%
df["rH"].plot()
# Out:
# <Axes: xlabel='starttime_dt'>

# %%
#loop for rounding to the hours
df["starttime_dt"] = [i.round("h") for i in df["starttime_dt"]]
df['DATETIME'] = df['starttime_dt']
df.index = df['DATETIME']
df = df.drop(columns=['starttime_dt'])
df
# Out:
#                      wind_s      T    rH       P            DATETIME
# DATETIME
# 2016-01-01 00:00:00    5.80 -12.60  85.3  798.50 2016-01-01 00:00:00
# 2016-01-01 01:00:00    6.10 -12.20  85.7  798.50 2016-01-01 01:00:00
# 2016-01-01 02:00:00    3.90 -11.60  87.0  798.50 2016-01-01 02:00:00
# 2016-01-01 03:00:00    1.20 -11.00  84.2  797.60 2016-01-01 03:00:00
# 2016-01-01 04:00:00    1.10 -10.90  83.5  796.70 2016-01-01 04:00:00
# ...                     ...    ...   ...     ...                 ...
# 2023-12-31 19:00:00    5.77   4.13  77.0  795.56 2023-12-31 19:00:00
# 2023-12-31 20:00:00    6.08   3.23  88.0  795.59 2023-12-31 20:00:00
# 2023-12-31 21:00:00    6.84   3.22  86.0  795.71 2023-12-31 21:00:00
# 2023-12-31 22:00:00    6.33   3.13  85.0  795.85 2023-12-31 22:00:00
# 2023-12-31 23:00:00    5.56   3.59  80.0  796.01 2023-12-31 23:00:00
#
# [56032 rows x 5 columns]

# %%
df = df.drop(columns=['DATETIME'])

# %%
df1 = df.set_axis([ 'wind_speed',  'temperature',  'relative_humidity',  'pressure'], axis=1)

# %%
df1
# Out:
#                      wind_speed  temperature  relative_humidity  pressure
# DATETIME
# 2016-01-01 00:00:00        5.80       -12.60               85.3    798.50
# 2016-01-01 01:00:00        6.10       -12.20               85.7    798.50
# 2016-01-01 02:00:00        3.90       -11.60               87.0    798.50
# 2016-01-01 03:00:00        1.20       -11.00               84.2    797.60
# 2016-01-01 04:00:00        1.10       -10.90               83.5    796.70
# ...                         ...          ...                ...       ...
# 2023-12-31 19:00:00        5.77         4.13               77.0    795.56
# 2023-12-31 20:00:00        6.08         3.23               88.0    795.59
# 2023-12-31 21:00:00        6.84         3.22               86.0    795.71
# 2023-12-31 22:00:00        6.33         3.13               85.0    795.85
# 2023-12-31 23:00:00        5.56         3.59               80.0    796.01
#
# [56032 rows x 4 columns]

# %%
df1.temperature.plot()
# Out:
# <Axes: xlabel='DATETIME'>

# %%
df1.relative_humidity.plot()
# Out:
# <Axes: xlabel='DATETIME'>

# %%
save_dir="C:\\YEAR1\\NMVOC\\Data\\data_Meteo"  

# Save final  DataFrame
output_file = os.path.join(save_dir, "processed_met_16_23.csv")
df1.to_csv(output_file, index=True)

print(f"Saved final data to: {output_file}")
# Out:
# Saved final data to: C:\YEAR1\NMVOC\Data\data_Meteo\processed_met_16_23.csv

# %%
print(df1.head())  # Shows the first 5 rows
# Out:
#                      wind_speed  temperature  relative_humidity  pressure
# DATETIME
# 2016-01-01 00:00:00         5.8       -12.60               85.3    798.50
# 2016-01-01 01:00:00         6.1        -0.50               62.5    791.00
# 2016-01-01 02:00:00         3.9        -4.50               96.0    773.10
# 2016-01-01 03:00:00         1.2        -0.90               99.8    782.50
# 2016-01-01 04:00:00         1.1         7.51               23.0    793.97
